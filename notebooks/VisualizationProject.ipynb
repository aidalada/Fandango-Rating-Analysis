# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/fandango_scrape.csv')
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
df2 = pd.read_csv('../data/fandango_score_comparison.csv')
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(data=df, x='RATING', y='VOTES', alpha=0.2)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
df['YEAR'] = df['FILM'].str.extract('\((\d{4})\)')
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %%
df['YEAR'].value_counts()
# Out:
# YEAR
# 2015    477
# 2014     24
# 2016      1
# 1964      1
# Name: count, dtype: int64

# %%
df['YEAR'] = df['YEAR'].fillna(0)

# %%
df['YEAR'] = df['YEAR'].astype(int)

# %%
df
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 505                      Valiyavan (2015)    0.0     0.0      0  2015
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 509                            Zarafa (1)    0.0     0.0      0     0
#
# [510 rows x 5 columns]

# %%
df = df.iloc[:-1]

# %%
df
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 504                      Two 4 One (2015)    0.0     0.0      0  2015
# 505                      Valiyavan (2015)    0.0     0.0      0  2015
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
#
# [509 rows x 5 columns]

# %%
sns.countplot(data=df, x='YEAR')
# Out:
# <Axes: xlabel='YEAR', ylabel='count'>

# %%
df.nlargest(10, 'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
len(df[df['VOTES'] == 0])
# Out:
# 72

# %%
fan = df[df['VOTES']>0]

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data=fan, x='RATING', clip=[0,5], fill=True, label='True Rating')
sns.kdeplot(data=fan, x='STARS', clip=[0,5], fill=True, label='Stars Rating')
plt.legend(loc=(1.05, 0.5))

# %%
df['DIFFERENCE'] = df['STARS'] - df['RATING']
df['DIFFERENCE'] = df['DIFFERENCE'].round(1)
# Out:
# C:\Users\aidal\AppData\Local\Temp\ipykernel_15012\3941879913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DIFFERENCE'] = df['STARS'] - df['RATING']
# C:\Users\aidal\AppData\Local\Temp\ipykernel_15012\3941879913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DIFFERENCE'] = df['DIFFERENCE'].round(1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='DIFFERENCE', hue='DIFFERENCE', palette='magma', legend=False)
# Out:
# <Axes: xlabel='DIFFERENCE', ylabel='count'>

# %%
df[df['DIFFERENCE'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %%
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df2, x='RottenTomatoes_User', y='RottenTomatoes')

plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
df2['RTDifference'] = df2['RottenTomatoes'] - df2['RottenTomatoes_User']
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# ...

# %%
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# ...

# %%
df2['RTDifference'].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
plt.figure(figsize=(12,6))
plt.title('RT Critics Score minus RT User Score')
sns.histplot(data=df2, x='RTDifference', kde=True, bins=25)
# Out:
# <Axes: title={'center': 'RT Critics Score minus RT User Score'}, xlabel='RTDifference', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x=df2['RTDifference'].apply(abs), kde=True, bins=20)
# Out:
# <Axes: xlabel='RTDifference', ylabel='Count'>

# %%
df2.nsmallest(5, 'RTDifference')[['FILM','RTDifference']]
# Out:
#                           FILM  RTDifference
# 3       Do You Believe? (2015)           -66
# 85           Little Boy (2015)           -61
# 105    Hitman: Agent 47 (2015)           -42
# 134    The Longest Ride (2015)           -42
# 125  The Wedding Ringer (2015)           -39

# %%
df2.nlargest(5, 'RTDifference')[['FILM', 'RTDifference']]
# Out:
#                                  FILM  RTDifference
# 69                  Mr. Turner (2014)            42
# 112                 It Follows (2015)            31
# 115          While We're Young (2015)            31
# 37               Welcome to Me (2015)            24
# 40   I'll See You In My Dreams (2015)            24

# %%
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# ...

# %%
plt.figure(figsize=(10,4), dpi=150)
sns.scatterplot(data=df2, x='Metacritic', y='Metacritic_User')
plt.xlim(0,100)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
df2.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df2, x='Metacritic_user_vote_count', y='IMDB_user_vote_count')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
df2.nlargest(1, 'IMDB_user_vote_count')[['FILM', 'IMDB_user_vote_count', 'Metacritic_user_vote_count']]
# Out:
#                          FILM  IMDB_user_vote_count  \
# 14  The Imitation Game (2014)                334164
#
#     Metacritic_user_vote_count
# 14                         566

# %%
df2.nlargest(1, 'Metacritic_user_vote_count')[['FILM', 'Metacritic_user_vote_count', 'IMDB_user_vote_count']]
# Out:
#                          FILM  Metacritic_user_vote_count  \
# 88  Mad Max: Fury Road (2015)                        2375
#
#     IMDB_user_vote_count
# 88                292023

# %%
df
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR  \
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 504                      Two 4 One (2015)    0.0     0.0      0  2015
# 505                      Valiyavan (2015)    0.0     0.0      0  2015
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
#
#      DIFFERENCE
# 0           0.1
# 1           0.0
# 2           0.2
# 3           0.2
# 4           0.0
# ..          ...
# ...

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                     86          66              7.1   7.8             5.0
# ...

# %%
pd.merge(df, df2, on='FILM')
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      DIFFERENCE  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0           0.1              25                   42          46
# ...

# %%
df = pd.merge(df, df2, on='FILM', how='inner')

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      DIFFERENCE  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0           0.1              25                   42          46
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    int32
#  5   DIFFERENCE                  145 non-null    float64
#  6   RottenTomatoes              145 non-null    int64
#  7   RottenTomatoes_User         145 non-null    int64
#  8   Metacritic                  145 non-null    int64
#  9   Metacritic_User             145 non-null    float64
#  10  IMDB                        145 non-null    float64
#  11  Fandango_Stars              145 non-null    float64
#  12  Fandango_Ratingvalue        145 non-null    float64
# ...

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      DIFFERENCE  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0           0.1              25                   42          46
# ...

# %%
mask = df.isna()
df[mask]
# Out:
#     FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE  RottenTomatoes  \
# 0    NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 1    NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 2    NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 3    NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 4    NaN    NaN     NaN    NaN   NaN         NaN             NaN
# ..   ...    ...     ...    ...   ...         ...             ...
# 140  NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 141  NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 142  NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 143  NaN    NaN     NaN    NaN   NaN         NaN             NaN
# 144  NaN    NaN     NaN    NaN   NaN         NaN             NaN
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  ...  RT_norm_round  \
# 0                    NaN         NaN              NaN  ...            NaN
# ...

# %%
df.isna().count()
# Out:
# FILM                          145
# STARS                         145
# RATING                        145
# VOTES                         145
# YEAR                          145
# DIFFERENCE                    145
# RottenTomatoes                145
# RottenTomatoes_User           145
# Metacritic                    145
# Metacritic_User               145
# IMDB                          145
# Fandango_Stars                145
# Fandango_Ratingvalue          145
# RT_norm                       145
# RT_user_norm                  145
# Metacritic_norm               145
# Metacritic_user_nom           145
# IMDB_norm                     145
# RT_norm_round                 145
# RT_user_norm_round            145
# Metacritic_norm_round         145
# Metacritic_user_norm_round    145
# IMDB_norm_round               145
# Metacritic_user_vote_count    145
# IMDB_user_vote_count          145
# Fandango_votes                145
# Fandango_Difference           145
# ...

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  ...  \
# 0              25                   42          46              3.2  ...
# 1              71                   81          59              7.0  ...
# 2              72                   85          72              6.6  ...
# 3              81                   84          67              6.8  ...
# 4              98                   90          94              8.9  ...
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# ...

# %%
df['RottenTomatoes'] = df['RottenTomatoes'] / 20

# %%
df['RottenTomatoes'] = df['RottenTomatoes'].round(1)

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      DIFFERENCE  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0           0.1             1.2                   42          46
# ...

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  ...  \
# 0             1.2                   42          46              3.2  ...
# 1             3.6                   81          59              7.0  ...
# 2             3.6                   85          72              6.6  ...
# 3             4.0                   84          67              6.8  ...
# 4             4.9                   90          94              8.9  ...
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# ...

# %%
df[['RottenTomatoes_User', 'Metacritic']] = df[['RottenTomatoes_User', 'Metacritic']] / 20

# %%
df[['RottenTomatoes_User', 'Metacritic']] = df[['RottenTomatoes_User', 'Metacritic']].round(1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  DIFFERENCE  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  ...  \
# 0             1.2                  2.1         2.3              3.2  ...
# 1             3.6                  4.0         3.0              7.0  ...
# 2             3.6                  4.2         3.6              6.6  ...
# 3             4.0                  4.2         3.4              6.8  ...
# 4             4.9                  4.5         4.7              8.9  ...
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# ...

# %%
norm_scores = pd.DataFrame()

# %%
norm_scores
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'DIFFERENCE',
#        'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Metacritic_user_vote_count', 'IMDB_user_vote_count',
#        'Fandango_votes', 'Fandango_Difference', 'RTDifference'],
#       dtype='object')

# %%
norm_scores = df[['FILM', 'STARS', 'RATING', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic', 'Metacritic_User']]

# %%
norm_scores.head()
# Out:
#                           FILM  STARS  RATING  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9             1.2
# 1        Jurassic World (2015)    4.5     4.5             3.6
# 2       American Sniper (2015)    5.0     4.8             3.6
# 3             Furious 7 (2015)    5.0     4.8             4.0
# 4            Inside Out (2015)    4.5     4.5             4.9
#
#    RottenTomatoes_User  Metacritic  Metacritic_User
# 0                  2.1         2.3              3.2
# 1                  4.0         3.0              7.0
# 2                  4.2         3.6              6.6
# 3                  4.2         3.4              6.8
# 4                  4.5         4.7              8.9

# %%
norm_scores.head()
# Out:
#                           FILM  STARS  RATING  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9             1.2
# 1        Jurassic World (2015)    4.5     4.5             3.6
# 2       American Sniper (2015)    5.0     4.8             3.6
# 3             Furious 7 (2015)    5.0     4.8             4.0
# 4            Inside Out (2015)    4.5     4.5             4.9
#
#    RottenTomatoes_User  Metacritic  Metacritic_User
# 0                  2.1         2.3              3.2
# 1                  4.0         3.0              7.0
# 2                  4.2         3.6              6.6
# 3                  4.2         3.4              6.8
# 4                  4.5         4.7              8.9

# %%
norm_scores.loc[:, 'Metacritic_User'] = norm_scores['Metacritic_User'] / 2

# %%
norm_scores.head()
# Out:
#                           FILM  STARS  RATING  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9             1.2
# 1        Jurassic World (2015)    4.5     4.5             3.6
# 2       American Sniper (2015)    5.0     4.8             3.6
# 3             Furious 7 (2015)    5.0     4.8             4.0
# 4            Inside Out (2015)    4.5     4.5             4.9
#
#    RottenTomatoes_User  Metacritic  Metacritic_User
# 0                  2.1         2.3             1.60
# 1                  4.0         3.0             3.50
# 2                  4.2         3.6             3.30
# 3                  4.2         3.4             3.40
# 4                  4.5         4.7             4.45

# %%
norm_scores.loc[:, 'Metacritic_User'] =  norm_scores['Metacritic_User'].round(1)

# %%
norm_scores.head()
# Out:
#                           FILM  STARS  RATING  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9             1.2
# 1        Jurassic World (2015)    4.5     4.5             3.6
# 2       American Sniper (2015)    5.0     4.8             3.6
# 3             Furious 7 (2015)    5.0     4.8             4.0
# 4            Inside Out (2015)    4.5     4.5             4.9
#
#    RottenTomatoes_User  Metacritic  Metacritic_User
# 0                  2.1         2.3              1.6
# 1                  4.0         3.0              3.5
# 2                  4.2         3.6              3.3
# 3                  4.2         3.4              3.4
# 4                  4.5         4.7              4.4

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(data=norm_scores, clip=[0,5], fill=True, palette='Set1')
# Out:
# <Axes: ylabel='Density'>

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
sns.kdeplot(data=norm_scores, clip=[0,5], fill=True, palette='Set1')
move_legend(ax, 'upper left')
# Out:
# C:\Users\aidal\AppData\Local\Temp\ipykernel_15012\191327130.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %%
norm_scores.head()
# Out:
#                           FILM  STARS  RATING  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9             1.2
# 1        Jurassic World (2015)    4.5     4.5             3.6
# 2       American Sniper (2015)    5.0     4.8             3.6
# 3             Furious 7 (2015)    5.0     4.8             4.0
# 4            Inside Out (2015)    4.5     4.5             4.9
#
#    RottenTomatoes_User  Metacritic  Metacritic_User
# 0                  2.1         2.3              1.6
# 1                  4.0         3.0              3.5
# 2                  4.2         3.6              3.3
# 3                  4.2         3.4              3.4
# 4                  4.5         4.7              4.4

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=norm_scores, bins=40)
# Out:
# <Axes: ylabel='Count'>

# %%
norm_scores = norm_scores.drop('FILM', axis=1)

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0    4.0     3.9             1.2                  2.1         2.3
# 1    4.5     4.5             3.6                  4.0         3.0
# 2    5.0     4.8             3.6                  4.2         3.6
# 3    5.0     4.8             4.0                  4.2         3.4
# 4    4.5     4.5             4.9                  4.5         4.7
#
#    Metacritic_User
# 0              1.6
# 1              3.5
# 2              3.3
# 3              3.4
# 4              4.4

# %%
sns.clustermap(data=norm_scores, cmap='magma', col_cluster=True, row_cluster=True, vmin=0, vmax=5)

# %%
norm_scores.nsmallest(10, 'RottenTomatoes')
# Out:
#     STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 49    3.5     3.5             0.2                  1.8         0.6
# 25    4.5     4.1             0.4                  2.3         1.3
# 28    3.0     2.7             0.4                  1.0         1.4
# 54    4.0     3.7             0.4                  1.8         1.6
# 84    4.0     3.9             0.4                  2.4         1.4
# 50    4.0     3.6             0.5                  1.8         1.5
# 77    3.5     3.2             0.6                  1.8         1.5
# 78    3.5     3.2             0.6                  1.5         1.4
# 83    3.5     3.3             0.6                  1.7         1.6
# 87    3.5     3.2             0.6                  1.4         1.6
#
#     Metacritic_User
# 49              1.2
# 25              2.3
# 28              1.2
# 54              1.8
# 84              1.6
# 50              2.8
# 77              2.0
# 78              1.6
# 83              2.5
# ...

# %%
norm_films = df[['STARS', 'RATING', 'RottenTomatoes', 'RottenTomatoes_User',
       'Metacritic', 'Metacritic_User', 'FILM']]

# %%
norm_scores.columns
# Out:
# Index(['STARS', 'RATING', 'RottenTomatoes', 'RottenTomatoes_User',
#        'Metacritic', 'Metacritic_User'],
#       dtype='object')

# %%
norm_films.nsmallest(10, 'RottenTomatoes')
# Out:
#     STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 49    3.5     3.5             0.2                  1.8         0.6
# 25    4.5     4.1             0.4                  2.3         1.3
# 28    3.0     2.7             0.4                  1.0         1.4
# 54    4.0     3.7             0.4                  1.8         1.6
# 84    4.0     3.9             0.4                  2.4         1.4
# 50    4.0     3.6             0.5                  1.8         1.5
# 77    3.5     3.2             0.6                  1.8         1.5
# 78    3.5     3.2             0.6                  1.5         1.4
# 83    3.5     3.3             0.6                  1.7         1.6
# 87    3.5     3.2             0.6                  1.4         1.6
#
#     Metacritic_User                           FILM
# 49              2.4  Paul Blart: Mall Cop 2 (2015)
# 25              4.6                 Taken 3 (2015)
# 28              2.5          Fantastic Four (2015)
# ...

# %%
norm_scores.loc[:, 'Metacritic_User'] = norm_scores['Metacritic_User'] / 2

# %%
norm_scores.loc[:, 'Metacritic_User'] = norm_scores['Metacritic_User'].round(1)

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0    4.0     3.9             1.2                  2.1         2.3
# 1    4.5     4.5             3.6                  4.0         3.0
# 2    5.0     4.8             3.6                  4.2         3.6
# 3    5.0     4.8             4.0                  4.2         3.4
# 4    4.5     4.5             4.9                  4.5         4.7
#
#    Metacritic_User
# 0              0.8
# 1              1.8
# 2              1.6
# 3              1.7
# 4              2.2

# %%
norm_films.loc[:, 'Metacritic_User'] = norm_films['Metacritic_User'] / 2

# %%
norm_films.loc[:, 'Metacritic_User'] = norm_films['Metacritic_User'].round(1)

# %%
worst_films = norm_films.nsmallest(10, 'RottenTomatoes')

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(data=worst_films, clip=[0,5], fill=True, palette='Set1')
# Out:
# <Axes: ylabel='Density'>

# %%
worst_films2 = norm_films.nsmallest(10, 'Metacritic')

# %%
worst_films2
# Out:
#     STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 49    3.5     3.5             0.2                  1.8         0.6
# 67    5.0     4.5             0.9                  4.2         1.1
# 79    3.5     3.4             0.8                  2.5         1.2
# 88    4.0     3.6             0.6                  2.0         1.2
# 25    4.5     4.1             0.4                  2.3         1.3
# 28    3.0     2.7             0.4                  1.0         1.4
# 40    4.5     4.1             0.8                  2.7         1.4
# 78    3.5     3.2             0.6                  1.5         1.4
# 81    3.5     3.0             0.7                  1.4         1.4
# 84    4.0     3.9             0.4                  2.4         1.4
#
#     Metacritic_User                           FILM
# 49              1.2  Paul Blart: Mall Cop 2 (2015)
# 67              2.4         Do You Believe? (2015)
# 79              2.6           Strange Magic (2015)
# ...

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(data=worst_films2, clip=[0,5], fill=True, palette='Set1')
# Out:
# <Axes: ylabel='Density'>

# %%
worst_films
# Out:
#     STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 49    3.5     3.5             0.2                  1.8         0.6
# 25    4.5     4.1             0.4                  2.3         1.3
# 28    3.0     2.7             0.4                  1.0         1.4
# 54    4.0     3.7             0.4                  1.8         1.6
# 84    4.0     3.9             0.4                  2.4         1.4
# 50    4.0     3.6             0.5                  1.8         1.5
# 77    3.5     3.2             0.6                  1.8         1.5
# 78    3.5     3.2             0.6                  1.5         1.4
# 83    3.5     3.3             0.6                  1.7         1.6
# 87    3.5     3.2             0.6                  1.4         1.6
#
#     Metacritic_User                           FILM
# 49              1.2  Paul Blart: Mall Cop 2 (2015)
# 25              2.3                 Taken 3 (2015)
# 28              1.2          Fantastic Four (2015)
# ...

# %%
taken3 = worst_films[worst_films['FILM'] == 'Taken 3 (2015)']

# %%
taken3
# Out:
#     STARS  RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 25    4.5     4.1             0.4                  2.3         1.3
#
#     Metacritic_User            FILM
# 25              2.3  Taken 3 (2015)

# %%
taken3_v = taken3[['RottenTomatoes', 'RottenTomatoes_User', 'Metacritic', 'Metacritic_User']].values

# %%
taken3_v
# Out:
# array([[0.4, 2.3, 1.3, 2.3]])

# %%
taken3_a = taken3_v.sum() / taken3_v.size

# %%
taken3_a
# Out:
# 1.575
